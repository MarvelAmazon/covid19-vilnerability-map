# %%
from os.path import dirname, join
import geopandas as gpd
import pandas as pd
from geopandas import GeoDataFrame
from shapely.geometry import Point
import matplotlib.pyplot as plt

# %%
sections_population=pd.read_excel("data/population/hti_adminboundaries_tabulardata.xlsx",sheet_name="hti_pop2019_adm3",index_col=14)
communes_population=pd.read_excel("data/population/hti_adminboundaries_tabulardata.xlsx",sheet_name="hti_pop2019_adm2", index_col=8)
departements_population=pd.read_excel("data/population/hti_adminboundaries_tabulardata.xlsx",sheet_name="hti_pop2019_adm1", index_col=4)

# %%
sections_population.head()
# Out:
#           id_Section  No_section adm0code adm0_en adm0_fr adm0_ht adm1code  \
# adm3code
# HT0111-01     111-01           1       HT   Haiti   Haïti   Ayiti     HT01
# HT0111-02     111-02           2       HT   Haiti   Haïti   Ayiti     HT01
# HT0111-03     111-03           3       HT   Haiti   Haïti   Ayiti     HT01
# HT0112-01     112-01           1       HT   Haiti   Haïti   Ayiti     HT01
# HT0113-01     113-01           1       HT   Haiti   Haïti   Ayiti     HT01
#
#           adm1_en adm1_fr adm1_ht adm2code         adm2_en         adm2_fr  \
# adm3code
# HT0111-01    West   Ouest    Lwès   HT0111  Port-au-Prince  Port-au-Prince
# HT0111-02    West   Ouest    Lwès   HT0111  Port-au-Prince  Port-au-Prince
# HT0111-03    West   Ouest    Lwès   HT0111  Port-au-Prince  Port-au-Prince
# HT0112-01    West   Ouest    Lwès   HT0112          Delmas          Delmas
# HT0113-01    West   Ouest    Lwès   HT0113       Carrefour       Carrefour
#
#           adm2_ht                      adm3_en                      adm3_fr  \
# adm3code
# HT0111-01                  1re Section Turgeau          1re Section Turgeau
# HT0111-02           2e Section Morne l'Hopital   2e Section Morne l'Hopital
# HT0111-03                3e Section Martissant        3e Section Martissant
# HT0112-01                1re Section St Martin        1re Section St Martin
# HT0113-01          1re Section Morne Chandelle  1re Section Morne Chandelle
#
#            IHSI_UNFPA_2019  IHSI_UNFPA_2019_female  IHSI_UNFPA_2019_male
# adm3code
# HT0111-01    660741.475769                  350627                310115
# HT0111-02    199766.395065                  105735                 94031
# HT0111-03    367032.456736                  191991                175042
# HT0112-01    491434.226379                  258526                232908
# HT0113-01       121.845187                      55                    67

# %%
communes_population.head()
# Out:
#          adm0code adm0_en adm0_fr adm0_ht adm1code adm1_en adm1_fr adm1_ht  \
# adm2code
# HT0111         HT   Haiti   Haïti   Ayiti     HT01    West   Ouest    Lwès
# HT0112         HT   Haiti   Haïti   Ayiti     HT01    West   Ouest    Lwès
# HT0113         HT   Haiti   Haïti   Ayiti     HT01    West   Ouest    Lwès
# HT0114         HT   Haiti   Haïti   Ayiti     HT01    West   Ouest    Lwès
# HT0115         HT   Haiti   Haïti   Ayiti     HT01    West   Ouest    Lwès
#
#                  adm2_en         adm2_fr adm2_ht  IHSI_UNFPA_2019  \
# adm2code
# HT0111    Port-au-Prince  Port-au-Prince             1.227540e+06
# HT0112            Delmas          Delmas             4.914342e+05
# HT0113         Carrefour       Carrefour             6.357646e+05
# HT0114      Petion-Ville    Pétion-Ville             4.685251e+05
# HT0115          Kenscoff        Kenscoff             7.140848e+04
#
#           IHSI_UNFPA_2019_female  IHSI_UNFPA_2019_male
# adm2code
# HT0111                    648353                579188
# HT0112                    258526                232908
# HT0113                    333500                302263
# HT0114                    241407                227118
# HT0115                     35608                 35800

# %%
departements_population.head()
# Out:
#          adm0code adm0_en adm0_fr adm0_ht     adm1_en     adm1_fr    adm1_ht  \
# adm1code
# HT01           HT   Haiti   Haïti   Ayiti        West       Ouest       Lwès
# HT02           HT   Haiti   Haïti   Ayiti  South-East     Sud-Est      Sidès
# HT03           HT   Haiti   Haïti   Ayiti       North        Nord         Nò
# HT04           HT   Haiti   Haïti   Ayiti  North-East    Nord-Est      Nòdès
# HT05           HT   Haiti   Haïti   Ayiti  Artibonite  Artibonite  Latibonit
#
#           IHSI_UNFPA_2019  IHSI_UNFPA_2019_female  IHSI_UNFPA_2019_male
# adm1code
# HT01         5.010206e+06                 2587360               2422846
# HT02         8.939007e+05                  448111                445790
# HT03         1.159762e+06                  589825                569932
# HT04         4.444631e+05                  221501                222966
# HT05         2.047153e+06                 1034065               1013085

# %%
#Select population data
pop_dep=departements_population[["IHSI_UNFPA_2019","IHSI_UNFPA_2019_female","IHSI_UNFPA_2019_male"]]
pop_com=communes_population[["IHSI_UNFPA_2019","IHSI_UNFPA_2019_female","IHSI_UNFPA_2019_male"]]
pop_sec=sections_population[["IHSI_UNFPA_2019","IHSI_UNFPA_2019_female","IHSI_UNFPA_2019_male"]]

# %%
display(pop_dep.head())
display(pop_com.head())
display(pop_sec.head())
# Out:
#           IHSI_UNFPA_2019  IHSI_UNFPA_2019_female  IHSI_UNFPA_2019_male
# adm1code
# HT01         5.010206e+06                 2587360               2422846
# HT02         8.939007e+05                  448111                445790
# HT03         1.159762e+06                  589825                569932
# HT04         4.444631e+05                  221501                222966
# HT05         2.047153e+06                 1034065               1013085
#           IHSI_UNFPA_2019  IHSI_UNFPA_2019_female  IHSI_UNFPA_2019_male
# adm2code
# HT0111       1.227540e+06                  648353                579188
# HT0112       4.914342e+05                  258526                232908
# HT0113       6.357646e+05                  333500                302263
# HT0114       4.685251e+05                  241407                227118
# HT0115       7.140848e+04                   35608                 35800
#            IHSI_UNFPA_2019  IHSI_UNFPA_2019_female  IHSI_UNFPA_2019_male
# adm3code
# HT0111-01    660741.475769                  350627                310115
# HT0111-02    199766.395065                  105735                 94031
# HT0111-03    367032.456736                  191991                175042
# HT0112-01    491434.226379                  258526                232908
# HT0113-01       121.845187                      55                    67

# %%
#read geodata file
sectionsgpd=gpd.read_file("data/adm/hti_admbnda_adm3_cnigs_20181129.shp")
communesgpd=gpd.read_file("data/adm/hti_admbnda_adm2_cnigs_20181129.shp")
departementsgpd=gpd.read_file("data/adm/hti_admbnda_adm1_cnigs_20181129.shp")

# %%
sectionsgpd.set_index("ADM3_PCODE", inplace=True)
communesgpd.set_index("ADM2_PCODE", inplace=True)
departementsgpd.set_index("ADM1_PCODE", inplace=True)
display(sectionsgpd.head())
# Out:
#             Shape_Leng  Shape_Area                   ADM3_EN  \
# ADM3_PCODE
# HT0131-10     0.548180    0.009233  10e Section des Orangers
# HT0122-10     0.277353    0.001740    10e Section des Palmes
# HT0121-10     0.274402    0.003068    10e Section Fond d'Oie
# HT0731-10     0.333814    0.003560       10e Section Guirand
# HT0211-10     0.331440    0.003103    10e Section La Vanneau
#
#                              ADM3_FR ADM3_HT               ADM3_REF  \
# ADM3_PCODE
# HT0131-10   10e Section des Orangers    None                   None
# HT0122-10     10e Section des Palmes    None                   None
# HT0121-10     10e Section Fond d'Oie    None  10e Section Fond dOie
# HT0731-10        10e Section Guirand    None                   None
# HT0211-10     10e Section La Vanneau    None                   None
#
#            ADM3ALT1EN ADM3ALT2EN ADM3ALT1FR ADM3ALT2FR  \
# ADM3_PCODE
# HT0131-10        None       None       None       None
# HT0122-10        None       None       None       None
# HT0121-10        None       None       None       None
# HT0731-10        None       None       None       None
# HT0211-10        None       None       None       None
#
#                                   ...                         ADM1_HT  \
# ADM3_PCODE                        ...
# HT0131-10                         ...                            Lwès
# HT0122-10                         ...                            Lwès
# HT0121-10                         ...                            Lwès
# HT0731-10                         ...                             Sid
# HT0211-10                         ...                           Sidès
#
#            ADM1_PCODE ADM0_EN ADM0_FR ADM0_HT ADM0_PCODE        date  \
# ADM3_PCODE
# HT0131-10        HT01   Haiti   Haïti   Ayiti         HT  2017-09-06
# HT0122-10        HT01   Haiti   Haïti   Ayiti         HT  2017-09-06
# HT0121-10        HT01   Haiti   Haïti   Ayiti         HT  2017-09-06
# HT0731-10        HT07   Haiti   Haïti   Ayiti         HT  2017-09-06
# HT0211-10        HT02   Haiti   Haïti   Ayiti         HT  2017-09-06
#
#                validOn validTo  \
# ADM3_PCODE
# HT0131-10   2018-11-29    None
# HT0122-10   2018-11-29    None
# HT0121-10   2018-11-29    None
# HT0731-10   2018-11-29    None
# HT0211-10   2018-11-29    None
#
#                                                      geometry
# ADM3_PCODE
# HT0131-10   POLYGON ((-72.29680323599996 18.81696379200002...
# HT0122-10   POLYGON ((-72.86124560499997 18.35838600300008...
# HT0121-10   POLYGON ((-72.52483078199998 18.40687415700006...
# HT0731-10   POLYGON ((-73.13994324699996 18.36475433600003...
# HT0211-10   POLYGON ((-72.62839603899994 18.29667571500005...
#
# [5 rows x 28 columns]

# %%
#reading facilities
facilities=pd.read_excel("data/health/haiti-healthsites_hdx.xlsx", skiprows=[1])
facilities.head()
# Out:
#    Adm1code adm1_fr adm1_ht adm2code         adm2_en         adm2_fr  \
# 0       NaN   Ouest    Lwès   HT0111  Port-au-Prince  Port-au-Prince
# 1       NaN   Ouest    Lwès   HT0111  Port-au-Prince  Port-au-Prince
# 2       NaN   Ouest    Lwès   HT0111  Port-au-Prince  Port-au-Prince
# 3       NaN   Ouest    Lwès   HT0111  Port-au-Prince  Port-au-Prince
# 4       NaN   Ouest    Lwès   HT0111  Port-au-Prince  Port-au-Prince
#
#     adm3code              adm3_en              adm3_fr  \
# 0  HT0111-01  1re Section Turgeau  1re Section Turgeau
# 1  HT0111-01  1re Section Turgeau  1re Section Turgeau
# 2  HT0111-01  1re Section Turgeau  1re Section Turgeau
# 3  HT0111-01  1re Section Turgeau  1re Section Turgeau
# 4  HT0111-01  1re Section Turgeau  1re Section Turgeau
#
#                      Institution name    Catégorie          Institution_Type  \
# 0              Centre de Santé Snelak  Dispensaire      Privé à but lucratif
# 1  Centre de psychiatrie Mars & Kline          HCR                    Public
# 2       Hôpital St. François de Salle          CSL      Privé à but lucratif
# 3                           CSL SODEC          CAL      Privé à but lucratif
# 4                          PROFAMIL 2          CSL  Privé à but non lucratif
#
#    Institution_Code      LatDD     LongDD
# 0          111607.0  18.525922 -72.335068
# 1          111616.0  18.525922 -72.335068
# 2          111618.0  18.537777 -72.344001
# 3          111619.0  18.525922 -72.335068
# 4          111620.0  18.525922 -72.335068

# %%
#Convert facilities to GeoDataFrame
geometry = [Point(xy) for xy in zip(facilities["LongDD"], facilities["LatDD"])]
facilities = facilities.drop(['LatDD', 'LongDD'], axis=1)
crs = {'init': 'epsg:4326'}
facilitiesgpd = GeoDataFrame(facilities, crs=crs, geometry=geometry)

# %%
facilities.columns
# Out:
# Index(['Adm1code', 'adm1_fr', 'adm1_ht', 'adm2code', 'adm2_en', 'adm2_fr',
#        'adm3code', 'adm3_en', 'adm3_fr', 'Institution name', 'Catégorie',
#        'Institution_Type', 'Institution_Code', 'geometry'],
#       dtype='object')

# %%
facilitiesgpd.plot()

# %%
#Add index
facilitiesgpd_dep=facilitiesgpd.set_index("adm1code")
facilitiesgpd_com=facilitiesgpd.set_index("adm2code")
facilitiesgpd_sec=facilitiesgpd.set_index("adm3code")
